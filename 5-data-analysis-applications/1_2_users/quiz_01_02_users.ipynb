# %% [markdown]
# # Анализ поведения пользователей

# %% [markdown]
# ## Вопрос 1.
# Что содержательно оценивает показатель lifetime value?
#
# * **lifetime value оценивает сколько в среднем денег принес пользователь за всё время использования сервиса**
# * lifetime value оценивает сколько в среднем времени пользователь провел на сервисе начиная с первого и до последнего визита в днях
# * lifetime value оценивает средний доход от пользователей сервиса в день
#
# ## Вопрос 2.
# Рассматривается сервис online игры. Как могут быть связаны между собой следующие показатели при условии, что по правилам игры пройти на уровень n можно только после прохождения всех уровней с 1 по (n-1) :
# > K_1_2: конверсия игроков первого уровня в игроков второго уровня;
# > K_1_3: конверсия игроков первого уровня в игроков третьего уровня.
#
# * K_1_2 <= K_1_3
# * **K_1_2 >= K_1_3**
# * K_1_2 = K_1_3
#
# ## Вопрос 3.
# Рассчитайте коэффициент возвращаемости инвестиции (ROI) в случае, если доход (total revenue) составил 1375 y.e., а расход (total cost) составил 987 y.e. Ответ округлите до 3го знака после запятой.

# %%
print(round((1375 - 987) * 100 / 987, 3))
# Out:
# 39.311

# %%
print(round(1375 * 100 / 987, 3))
# Out:
# 139.311

# %% [markdown]
# ## Вопрос 4.
# Решается задача бинарной классификации, и соотношение классов составляет 99%/1%. Классификация является несбалансированной. Для балансировки соотношения классов используется стратегия под названием undersampling. В чем заключается идея этой стратегии?
#
# * В задании весов для объектов таким образом, чтобы скомпенсировать количество объектов меньшего класса их важностью.
# * В генерации большего количества объектов меньшего класса.
# * **В исключении из обучения объектов преобладающего класса**
#
# ## Вопрос 5.
# Для чего при построении прогнозных моделей, например, модели прогнозирования оттока пользователей, используется так называемая отложенная выборка (hold-out dataset)?
#
# * Для обучения модели
# * Для оптимизации модели, в частности для подбора параметров.
# * **Для финальной проверки качества решения.**
